# %%
# !pip install tensorflow==1.15
# !git clone https://github.com/Sidray-Infinity/minor-project
# !rm -r sample_data

# %%
# !git clone https://github.com/tensorflow/models
# !pip install --user Cython contextlib2 pillow lxml
# !git clone https://github.com/cocodataset/cocoapi.git
# !cd cocoapi/PythonAPI; make
# !cp -r cocoapi/PythonAPI/pycocotools models/research
# !cd models/research; wget -O protobuf.zip https://github.com/protocolbuffers/protobuf/releases/download/v3.4.0/protoc-3.4.0-linux-x86_64.zip
# !cd models/research; unzip protobuf.zip
# !cd models/research; bin/protoc object_detection/protos/*.proto --python_out=.
# !cd models/research; python setup.py build
# !cd models/research; python setup.py install
# !cd models/research; export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
# !cp -r models/research/slim/nets minor-project/

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
# !cd minor-project; python model_main.py --model_dir=Training/Model/ --logtostderr --pipeline_config_path=Training/ssd_mobilenet_v1_coco_2018_01_28.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From model_main.py:113: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0205 14:41:14.471943 140706324944768 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# !cp -r minor-project/Training/Model drive/"My Drive"/
